# %% [markdown]
# # 🎵 Metanoia YuE Music Generator (Kaggle GPU)
# **Gerador de Louvores & Trap Gospel com IA Open-Source (YuE)**
# Ministério Metanoia // Pr. Matheus Barbosa
#
# Este notebook roda na GPU gratuita da Kaggle (NVIDIA T4 16GB ou P100 16GB) para gerar canções completas com voz cantada e instrumental estilo 2metro.

# %%
# 1. Verificar GPU NVIDIA alocada no Kaggle
# !nvidia-smi

# %%
# 2. Clonar o repositório YuE-UI e instalar dependências
import os
# !git clone https://github.com/joeljuvel/YuE-UI.git /kaggle/working/YuE-UI
# %cd /kaggle/working/YuE-UI
# !pip install --no-cache-dir -r requirements.txt
# !pip install --no-cache-dir gradio soundfile

# %%
# 3. Iniciar a WebUI (Gradio com link público share=True)
# Clique no link https://xxxx.gradio.live que aparecer no console abaixo para abrir o estúdio no seu navegador!
# %cd /kaggle/working/YuE-UI
# !python app.py --share --cuda

# %%
# 4. Salvar e organizar os áudios gerados no output do Kaggle
# !mkdir -p /kaggle/working/musicas_metanoia
# !cp -rf /kaggle/working/YuE-UI/outputs/* /kaggle/working/musicas_metanoia/ 2>/dev/null || true
# !ls -lh /kaggle/working/musicas_metanoia/
